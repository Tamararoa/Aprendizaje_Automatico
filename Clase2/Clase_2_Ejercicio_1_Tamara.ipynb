# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamararoa/Aprendizaje_Automatico/blob/main/Clase2/Clase_2_Ejercicio_1_Tamara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1 - 1

# %%
import pandas as pd
ventas = pd.read_csv ("/content/ventas.csv", encoding="ISO-8859-1",index_col= "id_venta")
ventas.head ()
# Out:
#                fecha id_cliente id_producto  cantidad  precio_unitario  \
# id_venta
# 1001      2026-08-02       C003        P003         3           3500.0
# 1002      2026-08-02       C010        P004         3          15000.0
# 1003      2026-08-10       C002        P001         3          12000.0
# 1004      2026-08-04       C001        P001         2          12000.0
# 1005      2026-08-05       C001        P005         1          85000.0
#
#           monto_total
# id_venta
# 1001          10500.0
# 1002          45000.0
# 1003          36000.0
# 1004          24000.0
# 1005          85000.0

# %% [markdown]
# Ejercicio 1-2

# %%
import pandas as pd
clientes = pd.read_json ("/content/clientes.json")
cantidad_clientes = len(clientes)
print("Total de clientes:", cantidad_clientes)
# Out:
# Total de clientes: 10

# %% [markdown]
# Ejercicio 1-3

# %%
import pandas as pd
inventario = pd.read_excel ("/content/inventario.xlsx")
promedio_stock = inventario["stock_disponible"].mean()
print(f"El promedio de stock disponible es:{promedio_stock}")
# Out:
# El promedio de stock disponible es:44.416666666666664
